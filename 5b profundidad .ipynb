# %% [markdown]
# # Actividad :  Resolución de problema mediante búsqueda heurística

# %%
# !pip install simpleai flask pydot graphviz
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting simpleai
#   Downloading simpleai-0.8.3.tar.gz (94 kB)
#      |████████████████████████████████| 94 kB 1.1 MB/s
# Requirement already satisfied: flask in /usr/local/lib/python3.8/dist-packages (1.1.4)
# Requirement already satisfied: pydot in /usr/local/lib/python3.8/dist-packages (1.3.0)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.8/dist-packages (0.10.1)
# Requirement already satisfied: Werkzeug<2.0,>=0.15 in /usr/local/lib/python3.8/dist-packages (from flask) (1.0.1)
# Requirement already satisfied: Jinja2<3.0,>=2.10.1 in /usr/local/lib/python3.8/dist-packages (from flask) (2.11.3)
# Requirement already satisfied: click<8.0,>=5.1 in /usr/local/lib/python3.8/dist-packages (from flask) (7.1.2)
# Requirement already satisfied: itsdangerous<2.0,>=0.24 in /usr/local/lib/python3.8/dist-packages (from flask) (1.1.0)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.8/dist-packages (from Jinja2<3.0,>=2.10.1->flask) (2.0.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /usr/local/lib/python3.8/dist-packages (from pydot) (3.0.9)
# Building wheels for collected packages: simpleai
#   Building wheel for simpleai (setup.py) ... done
#   Created wheel for simpleai: filename=simpleai-0.8.3-py3-none-any.whl size=101000 sha256=1ebb8fe982a0141fa5c55233fa88f8756e3bde9e6df035d436a516efeb1a60bf
#   Stored in directory: /root/.cache/pip/wheels/5d/2d/67/00b435b82fb8b17a0835aa94f2c614a6dd4b375837c0071be0
# Successfully built simpleai
# Installing collected packages: simpleai
# Successfully installed simpleai-0.8.3

# %% [markdown]
# ### modificación del mapa
# ##### punto 5b

# %%
#!/usr/bin/env python
# coding: utf-8

# 2022 Modified by: Alejandro Cervantes
# Remember installing pyplot and flask if you want to use WebViewer

# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search import SearchProblem, astar, breadth_first, depth_first
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer


MAP = """

########
#     t#
# #### #
#   p# #
# ##   #
#      #
########

"""
MAP = [list(x) for x in MAP.split("\n") if x]

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}


class GameWalkPuzzle(SearchProblem):

    def __init__(self, board):
        self.board = board
        self.goal = (0, 0)
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(COSTS.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return COSTS[action]

    def heuristic(self, state):
        x, y = state
        gx, gy = self.goal
        return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)


def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost

    
    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))
        
    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]
        
        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res

# %%
#!/usr/bin/env python
# coding: utf-8

# 2022 Modified by: Alejandro Cervantes
# Remember installing pyplot and flask if you want to use WebViewer

# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search import SearchProblem, astar, breadth_first, depth_first
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer


MAP = """

########
#     t#
# #### #
#   p# #
# ##   #
#      #
########

"""
MAP = [list(x) for x in MAP.split("\n") if x]

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}


class GameWalkPuzzle(SearchProblem):

    def __init__(self, board):
        self.board = board
        self.goal = (0, 0)
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(COSTS.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return COSTS[action]

    def heuristic(self, state):
        x, y = state
        gx, gy = self.goal
        return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)


def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost

    
    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))
        
    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]
        
        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res

# %%
def resultado_experimento(problem,MAP,result,used_viewer):
    path = [x[1] for x in result.path()]

    for y in range(len(MAP)):
        for x in range(len(MAP[y])):
            if (x, y) == problem.initial:
                print("T", end='')
            elif (x, y) == problem.goal:
                print("P", end='')
            elif (x, y) in path:
                print("·", end='')
            else:
                print(MAP[y][x], end='')
        print()

    info=searchInfo(problem,result,used_viewer)
    print(info)

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main()
# Out:
# ########
# #     T#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 7
# Total cost of solution: 6.0
# max fringe size: 3
# visited nodes: 15
# iterations: 15
#
# ########
# #·····T#
# #·#### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 11
# Total cost of solution: 10.0
# max fringe size: 3
# visited nodes: 11
# iterations: 11
#
# ########
# #     T#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 7
# Total cost of solution: 6.0
# max fringe size: 5
# visited nodes: 10
# iterations: 10

# %% [markdown]
# ### visualización paso a paso

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main()
# Out:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(6, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 2)>, Node <(5, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(5, 1)>, Node <(6, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(5, 1)>]
# Successors: [[Node <(6, 1)>, Node <(4, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 3)>, Node <(4, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 1)>, Node <(6, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 4)>, Node <(3, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 1)>, Node <(6, 5)>, Node <(5, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(6, 5)>, Node <(5, 4)>, Node <(2, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 5)>]
# Successors: [[Node <(6, 4)>, Node <(5, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 4)>, Node <(2, 1)>, Node <(5, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 1)>, Node <(5, 5)>, Node <(4, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 5)>, Node <(4, 4)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(5, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(5, 5)>]
# Successors: [[Node <(5, 4)>, Node <(6, 5)>, Node <(4, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 4)>, Node <(1, 1)>, Node <(4, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 1)>, Node <(4, 5)>, Node <(4, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 5)>, Node <(4, 3)>, Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 5)>]
# Successors: [[Node <(4, 4)>, Node <(5, 5)>, Node <(3, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 3)>, Node <(1, 2)>, Node <(3, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (6, 1)), ('down', (6, 2)), ('down', (6, 3)), ('down', (6, 4)), ('left', (5, 4)), ('left', (4, 4)), ('up', (4, 3))]
# >
# ########
# #     T#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 7
# Total cost of solution: 6.0
# max fringe size: 3
# visited nodes: 15
# iterations: 15
#
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(6, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(5, 1)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(5, 1)>]
# Successors: [[Node <(6, 1)>, Node <(4, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 1)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(3, 1)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(2, 1)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(3, 1)>, Node <(1, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(1, 1)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(1, 2)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(1, 3)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 3)>, Node <(1, 4)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 3)>, Node <(1, 4)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 3)>, Node <(1, 4)>, Node <(6, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (6, 1)), ('left', (5, 1)), ('left', (4, 1)), ('left', (3, 1)), ('left', (2, 1)), ('left', (1, 1)), ('down', (1, 2)), ('down', (1, 3)), ('right', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]
# >
# ########
# #·····T#
# #·#### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 11
# Total cost of solution: 10.0
# max fringe size: 3
# visited nodes: 11
# iterations: 11
#
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(6, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 1)>]
# Successors: [[Node <(6, 2)>, Node <(5, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 2)>, Node <(5, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 2)>]
# Successors: [[Node <(6, 1)>, Node <(6, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(5, 1)>, Node <(6, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(5, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(5, 1)>]
# Successors: [[Node <(6, 1)>, Node <(4, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 3)>, Node <(4, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 3)>]
# Successors: [[Node <(6, 2)>, Node <(6, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(4, 1)>, Node <(6, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 2 elements in the fringe:
# [Node <(6, 4)>, Node <(3, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(6, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(6, 4)>]
# Successors: [[Node <(6, 3)>, Node <(6, 5)>, Node <(5, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 1)>, Node <(5, 4)>, Node <(6, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(5, 4)>, Node <(6, 5)>, Node <(2, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(5, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(5, 4)>]
# Successors: [[Node <(5, 5)>, Node <(6, 4)>, Node <(4, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 4)>, Node <(6, 5)>, Node <(2, 1)>, Node <(5, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 4)>]
# Successors: [[Node <(4, 3)>, Node <(4, 5)>, Node <(5, 4)>]]
# >
# EVENT: new_iteration
# New iteration with 5 elements in the fringe:
# [Node <(4, 3)>, Node <(6, 5)>, Node <(2, 1)>, Node <(5, 5)>, Node <(4, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (6, 1)), ('down', (6, 2)), ('down', (6, 3)), ('down', (6, 4)), ('left', (5, 4)), ('left', (4, 4)), ('up', (4, 3))]
# >
# ########
# #     T#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 7
# Total cost of solution: 6.0
# max fringe size: 5
# visited nodes: 10
# iterations: 10

# %% [markdown]
# ### iteración 2

# %%
#!/usr/bin/env python
# coding: utf-8

# 2022 Modified by: Alejandro Cervantes
# Remember installing pyplot and flask if you want to use WebViewer

# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search import SearchProblem, astar, breadth_first, depth_first
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer


MAP = """

########
#t     #
# #### #
#   p# #
# ##   #
#      #
########

"""
MAP = [list(x) for x in MAP.split("\n") if x]

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}


class GameWalkPuzzle(SearchProblem):

    def __init__(self, board):
        self.board = board
        self.goal = (0, 0)
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(COSTS.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return COSTS[action]

    def heuristic(self, state):
        x, y = state
        gx, gy = self.goal
        return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)


def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost

    
    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))
        
    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]
        
        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res

# %%
def resultado_experimento(problem,MAP,result,used_viewer):
    path = [x[1] for x in result.path()]

    for y in range(len(MAP)):
        for x in range(len(MAP[y])):
            if (x, y) == problem.initial:
                print("T", end='')
            elif (x, y) == problem.goal:
                print("P", end='')
            elif (x, y) in path:
                print("·", end='')
            else:
                print(MAP[y][x], end='')
        print()

    info=searchInfo(problem,result,used_viewer)
    print(info)

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main()
# Out:
# ########
# #T     #
# #·#### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 6
# Total cost of solution: 5.0
# max fringe size: 3
# visited nodes: 13
# iterations: 13
#
# ########
# #T·····#
# # ####·#
# #   P#·#
# # ##···#
# #      #
# ########
# Total length of solution: 12
# Total cost of solution: 11.0
# max fringe size: 5
# visited nodes: 20
# iterations: 20
#
# ########
# #T     #
# #·#### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 6
# Total cost of solution: 5.0
# max fringe size: 3
# visited nodes: 9
# iterations: 9

# %% [markdown]
# ##### se descarta esta iteración por el número elevado de nodos

# %% [markdown]
# ### modificación de estado inicial para algoritmo en profunidad

# %% [markdown]
# ### iteración 3
# ### Se deja esta opción porque permite evaluar la profunidad y es obtener el menor coste

# %%
#!/usr/bin/env python
# coding: utf-8

# 2022 Modified by: Alejandro Cervantes
# Remember installing pyplot and flask if you want to use WebViewer

# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search import SearchProblem, astar, breadth_first, depth_first
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer


MAP = """

########
#      #
#t ### #
#   p# #
# ##   #
#      #
########

"""
MAP = [list(x) for x in MAP.split("\n") if x]

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}


class GameWalkPuzzle(SearchProblem):

    def __init__(self, board):
        self.board = board
        self.goal = (0, 0)
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(COSTS.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return COSTS[action]

    def heuristic(self, state):
        x, y = state
        gx, gy = self.goal
        return math.sqrt((x - gx) ** 2 + (y - gy) ** 2)


def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost

    
    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))
        
    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]
        
        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res

# %%
def resultado_experimento(problem,MAP,result,used_viewer):
    path = [x[1] for x in result.path()]

    for y in range(len(MAP)):
        for x in range(len(MAP[y])):
            if (x, y) == problem.initial:
                print("T", end='')
            elif (x, y) == problem.goal:
                print("P", end='')
            elif (x, y) in path:
                print("·", end='')
            else:
                print(MAP[y][x], end='')
        print()

    info=searchInfo(problem,result,used_viewer)
    print(info)

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main()
# Out:
# ########
# #      #
# #T ### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 13
# iterations: 13
#
# ########
# #      #
# #T·### #
# # ··P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 5
# iterations: 5
#
# ########
# #      #
# #T·### #
# # ··P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 6
# iterations: 6

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main()
# Out:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 3)>, Node <(2, 2)>, Node <(2, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 2)>, Node <(2, 1)>, Node <(1, 4)>, Node <(2, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 2)>]
# Successors: [[Node <(2, 1)>, Node <(2, 3)>, Node <(1, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 1)>, Node <(1, 4)>, Node <(2, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(2, 2)>, Node <(3, 1)>, Node <(1, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 4)>, Node <(2, 3)>, Node <(3, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 4)>]
# Successors: [[Node <(1, 3)>, Node <(1, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 3)>, Node <(3, 1)>, Node <(1, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(2, 2)>, Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 1)>, Node <(1, 5)>, Node <(3, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 5)>, Node <(3, 3)>, Node <(4, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 5)>]
# Successors: [[Node <(1, 4)>, Node <(2, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 3)>, Node <(4, 1)>, Node <(2, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 1)>, Node <(2, 5)>, Node <(4, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 5)>, Node <(4, 3)>, Node <(5, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 5)>]
# Successors: [[Node <(3, 5)>, Node <(1, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 3)>, Node <(5, 1)>, Node <(3, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (1, 2)), ('down', (1, 3)), ('right', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]
# >
# ########
# #      #
# #T ### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 13
# iterations: 13
#
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 2)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 2)>]
# Successors: [[Node <(2, 1)>, Node <(2, 3)>, Node <(1, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 3)>, Node <(2, 1)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(2, 2)>, Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(3, 3)>, Node <(2, 1)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 1)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (1, 2)), ('right', (2, 2)), ('down', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]
# >
# ########
# #      #
# #T·### #
# # ··P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 5
# iterations: 5
#
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 2)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 2)>]
# Successors: [[Node <(2, 1)>, Node <(2, 3)>, Node <(1, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(1, 3)>, Node <(2, 3)>, Node <(1, 1)>, Node <(2, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 3)>, Node <(1, 1)>, Node <(2, 1)>, Node <(1, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(2, 2)>, Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(3, 3)>, Node <(1, 1)>, Node <(2, 1)>, Node <(1, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 3)>, Node <(1, 1)>, Node <(2, 1)>, Node <(1, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (1, 2)), ('right', (2, 2)), ('down', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]

# %% [markdown]
# ### cálculo con manhatan

# %%
#!/usr/bin/env python
# coding: utf-8

# 2022 Modified by: Alejandro Cervantes
# Remember installing pyplot and flask if you want to use WebViewer

# NOTA: WebViewer sólo funcionará si ejecutáis en modo local

from __future__ import print_function

import math
from simpleai.search import SearchProblem, astar, breadth_first, depth_first
from simpleai.search.viewers import BaseViewer,ConsoleViewer,WebViewer


MAP = """
########
#      #
#t ### #
#   p# #
# ##   #
#      #
########
"""
MAP = [list(x) for x in MAP.split("\n") if x]

COSTS = {
    "up": 1.0,
    "down": 1.0,
    "right": 1.0,
    "left": 1.0,
}


class GameWalkPuzzle(SearchProblem):

    def __init__(self, board):
        self.board = board
        self.goal = (0, 0)
        for y in range(len(self.board)):
            for x in range(len(self.board[y])):
                if self.board[y][x].lower() == "t":
                    self.initial = (x, y)
                elif self.board[y][x].lower() == "p":
                    self.goal = (x, y)

        super(GameWalkPuzzle, self).__init__(initial_state=self.initial)

    def actions(self, state):
        actions = []
        for action in list(COSTS.keys()):
            newx, newy = self.result(state, action)
            if self.board[newy][newx] != "#":
                actions.append(action)
        return actions

    def result(self, state, action):
        x, y = state

        if action.count("up"):
            y -= 1
        if action.count("down"):
            y += 1
        if action.count("left"):
            x -= 1
        if action.count("right"):
            x += 1

        new_state = (x, y)
        return new_state

    def is_goal(self, state):
        return state == self.goal

    def cost(self, state, action, state2):
        return COSTS[action]

      
    def heuristic(self, state):
        x, y = state
        gx, gy = self.goal
        return abs(x - gx) + abs(y - gy)


def searchInfo (problem,result,use_viewer):
    def getTotalCost (problem,result):
        originState = problem.initial_state
        totalCost = 0
        for action,endingState in result.path():
            if action is not None:
                totalCost += problem.cost(originState,action,endingState)
                originState = endingState
        return totalCost

    
    res = "Total length of solution: {0}\n".format(len(result.path()))
    res += "Total cost of solution: {0}\n".format(getTotalCost(problem,result))
        
    if use_viewer:
        stats = [{'name': stat.replace('_', ' '), 'value': value}
                         for stat, value in list(use_viewer.stats.items())]
        
        for s in stats:
            res+= '{0}: {1}\n'.format(s['name'],s['value'])
    return res

# %%
def resultado_experimento(problem,MAP,result,used_viewer):
    path = [x[1] for x in result.path()]

    for y in range(len(MAP)):
        for x in range(len(MAP[y])):
            if (x, y) == problem.initial:
                print("T", end='')
            elif (x, y) == problem.goal:
                print("P", end='')
            elif (x, y) in path:
                print("·", end='')
            else:
                print(MAP[y][x], end='')
        print()

    info=searchInfo(problem,result,used_viewer)
    print(info)

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=BaseViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main()
# Out:
# ########
# #      #
# #T ### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 13
# iterations: 13
#
# ########
# #      #
# #T·### #
# # ··P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 5
# iterations: 5
#
# ########
# #      #
# #T ### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 6
# iterations: 6

# %%
def main():
    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    # Probad también ConsoleViewer para depurar
    # No podréis usar aquí WebViewer en Collab para ver los árboles
    
    # Mostramos tres experimentos
    result = breadth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)
    
    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    result = depth_first(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

    problem = GameWalkPuzzle(MAP)
    used_viewer=ConsoleViewer() 
    result = astar(problem, graph_search=True,viewer=used_viewer)
    resultado_experimento(problem,MAP,result,used_viewer)

# %%
main ()
# Out:
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 1)>]
# Successors: [[Node <(1, 2)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 3)>, Node <(2, 2)>, Node <(2, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 2)>, Node <(2, 1)>, Node <(1, 4)>, Node <(2, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 2)>]
# Successors: [[Node <(2, 1)>, Node <(2, 3)>, Node <(1, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 1)>, Node <(1, 4)>, Node <(2, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 1)>]
# Successors: [[Node <(2, 2)>, Node <(3, 1)>, Node <(1, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 4)>, Node <(2, 3)>, Node <(3, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 4)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 4)>]
# Successors: [[Node <(1, 3)>, Node <(1, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 3)>, Node <(3, 1)>, Node <(1, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(2, 2)>, Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 1)>, Node <(1, 5)>, Node <(3, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 1)>]
# Successors: [[Node <(4, 1)>, Node <(2, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 5)>, Node <(3, 3)>, Node <(4, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 5)>]
# Successors: [[Node <(1, 4)>, Node <(2, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(3, 3)>, Node <(4, 1)>, Node <(2, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 1)>, Node <(2, 5)>, Node <(4, 3)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 1)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(4, 1)>]
# Successors: [[Node <(5, 1)>, Node <(3, 1)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 5)>, Node <(4, 3)>, Node <(5, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 5)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 5)>]
# Successors: [[Node <(3, 5)>, Node <(1, 5)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(4, 3)>, Node <(5, 1)>, Node <(3, 5)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (1, 2)), ('down', (1, 3)), ('right', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]
# >
# ########
# #      #
# #T ### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 13
# iterations: 13
#
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(2, 2)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 2)>]
# Successors: [[Node <(2, 1)>, Node <(2, 3)>, Node <(1, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 3)>, Node <(2, 1)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(2, 2)>, Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(3, 3)>, Node <(2, 1)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 1)>, Node <(1, 3)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (1, 2)), ('right', (2, 2)), ('down', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]
# >
# ########
# #      #
# #T·### #
# # ··P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 5
# iterations: 5
#
# After each step, a prompt will be shown.
# On the prompt, you can just press Enter to continue to the next step.
# But you can also have this commands:
# (write the command you want to use and then press Enter)
# * h: get help.
# * g PATH_TO_PNG_IMAGE: create png with graph of the current state.
# * e: run non-interactively to the end of the algorithm.
# * s: show statistics of the execution (max fringe size, visited nodes).
# * q: quit program.
# EVENT: started
# Algorithm just started.
# >
# EVENT: new_iteration
# New iteration with 1 elements in the fringe:
# [Node <(1, 2)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 2)>]
# Successors: [[Node <(1, 1)>, Node <(1, 3)>, Node <(2, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 3 elements in the fringe:
# [Node <(1, 3)>, Node <(2, 2)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(1, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(1, 3)>]
# Successors: [[Node <(1, 2)>, Node <(1, 4)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 2)>, Node <(2, 3)>, Node <(1, 4)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 2)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 2)>]
# Successors: [[Node <(2, 1)>, Node <(2, 3)>, Node <(1, 2)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(2, 3)>, Node <(1, 1)>, Node <(1, 4)>, Node <(2, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(2, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(2, 3)>]
# Successors: [[Node <(2, 2)>, Node <(3, 3)>, Node <(1, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(3, 3)>, Node <(1, 4)>, Node <(2, 1)>, Node <(1, 1)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(3, 3)>
# Not goal
# >
# EVENT: expanded
# Expanded [Node <(3, 3)>]
# Successors: [[Node <(4, 3)>, Node <(2, 3)>]]
# >
# EVENT: new_iteration
# New iteration with 4 elements in the fringe:
# [Node <(4, 3)>, Node <(2, 1)>, Node <(1, 1)>, Node <(1, 4)>]
# >
# EVENT: chosen_node
# Chosen node: Node <(4, 3)>
# Is goal!
# >
# EVENT: finished
# Finished algorithm returning Node <(4, 3)>.
# Solution type: goal found
# Path from initial to goal: [(None, (1, 2)), ('down', (1, 3)), ('right', (2, 3)), ('right', (3, 3)), ('right', (4, 3))]
# >
# ########
# #      #
# #T ### #
# #···P# #
# # ##   #
# #      #
# ########
# Total length of solution: 5
# Total cost of solution: 4.0
# max fringe size: 4
# visited nodes: 6
# iterations: 6
